# %% [markdown]
# # Kebreab Methane Database
#
# Executable notebook wrapper for the Zenodo v2 methane-yield workflow.

# %%
import subprocess, sys
subprocess.run([sys.executable, 'research/studies/kebreab/methane-database-2024/run.py'], check=True)
