# %% [markdown]
# # GreenFeed Provenance
#
# Executable notebook wrapper for the published-protocol case study.

# %%
import subprocess, sys
subprocess.run([sys.executable, 'research/studies/kebreab/greenfeed/run.py'], check=True)
